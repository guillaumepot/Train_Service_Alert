# %%
import requests
from google.transit import gtfs_realtime_pb2

# %%
def fetch_gtfs_rt(url:str) -> gtfs_realtime_pb2.FeedMessage:
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        feed = gtfs_realtime_pb2.FeedMessage()
        feed.ParseFromString(response.content)
        return feed
    except Exception as e:
        print(e)
        return None

# %% [markdown]
# ### GTFS RT Trip Updates

# %%
GTFS_RT_TU_URL='https://proxy.transport.data.gouv.fr/resource/sncf-all-gtfs-rt-trip-updates'
feed = fetch_gtfs_rt(GTFS_RT_TU_URL)

# %%
all_data = []
all_ids = []
if feed:
    for entity in feed.entity:
        entity_data = {}
        entity_data['id'] = entity.id
        all_ids.append(entity.id)
        entity_data['trip_update'] = entity.trip_update
        all_data.append(entity_data)

# %% [markdown]
# ### GTFS RT SA

# %%
GTFS_RT_SA_URL='https://proxy.transport.data.gouv.fr/resource/sncf-gtfs-rt-service-alerts'
feed = fetch_gtfs_rt(GTFS_RT_SA_URL)

# %%
feed
# Out:
# header {
#   gtfs_realtime_version: "1.0"
#   incrementality: FULL_DATASET
#   timestamp: 1751450192
# }
# entity {
#   id: "QOM:Broadcast::2332929292503568220:LOC"
#   alert {
#     active_period {
#       start: 1750802400
#       end: 1751666340
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN847906F"
#       }
#     }
#     effect: UNKNOWN_EFFECT
#     header_text {
#       translation {
#         text: "AFFLUENCE3"
#         language: "de"
#       }
#       translation {
#         text: "AFFLUENCIA3"
#         language: "es"
#       }
#       translation {
#         text: "AFFLUENCE3"
#         language: "fr"
#       }
#       translation {
#         text: "AFFLUENCE3"
#         language: "en"
#       }
#       translation {
#         text: "AFFLUENZA3"
#         language: "it"
#       }
#       translation {
#         text: "AFFLUENCE3"
#         language: "nl"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Der Zug fährt mit eingeschränkter Kapazität, bis er im Oktober 2025 durch neues Material ersetzt wird. </p>"
#         language: "de"
#       }
#       translation {
#         text: "<p>El tren circulará con capacidad reducida hasta que sea sustituido por material nuevo en octubre de 2025. </p>"
#         language: "es"
#       }
#       translation {
#         text: "<p>Ce train circule avec une capacité réduite jusqu\'à son remplacement par un nouveau matériel courant octobre 2025 </p>"
#         language: "fr"
#       }
#       translation {
#         text: "<p>This Train runs at reduced capacity until it is replaced by new equipment in October 2025. </p>"
#         language: "en"
#       }
#       translation {
#         text: "<p>Il treno funzionerà a capacità ridotta fino alla sua sostituzione con un nuovo equipaggiamento nell\'ottobre 2025. </p>"
#         language: "it"
#       }
#       translation {
#         text: "<p>Deze trein zal met verminderde capaciteit rijden tot hij in oktober 2025 wordt vervangen door nieuw materieel. </p>"
#         language: "nl"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::2275413989368032491:LOC"
#   alert {
#     active_period {
#       start: 1750845180
#       end: 1756677540
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43901R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43903R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43902R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43909R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43908R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43905R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43907R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43906R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43912R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43911R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43914R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43913R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43910R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43919R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43916R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43915R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43918R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43917R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43923R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43922R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43921R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43920R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43927R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43926R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43929R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43928R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43945R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43944R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43947R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43946R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43943R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43942R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43948R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN43950R"
#       }
#     }
#     effect: UNKNOWN_EFFECT
#     header_text {
#       translation {
#         text: "Verschieben der Haltestelle"
#         language: "de"
#       }
#       translation {
#         text: "Déplacement de l\'arrêt"
#         language: "fr"
#       }
#       translation {
#         text: "Desplazamiento del tope"
#         language: "es"
#       }
#       translation {
#         text: "Move stop"
#         language: "en"
#       }
#       translation {
#         text: "Spostamento dell\'arresto"
#         language: "it"
#       }
#       translation {
#         text: "De stop verplaatsen"
#         language: "nl"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Die Haltestelle \"Gare\" in Bitche wird während der gesamten Bauzeit vor das Bahnhofsrestaurant verlegt. </p>"
#         language: "de"
#       }
#       translation {
#         text: "<p>L\' arrêt \"Gare\" à Bitche est déplacé devant le restaurant de la gare durant toute la durée des travaux. </p>"
#         language: "fr"
#       }
#       translation {
#         text: "<p>La parada \"Gare\" de Bitche se ha trasladado a la Parte delantera del restaurante de la estación mientras duren las obras. </p>"
#         language: "es"
#       }
#       translation {
#         text: "<p>The \"Gare\" stop in Bitche has been moved to In front of the station restaurant for the duration of the work. </p>"
#         language: "en"
#       }
#       translation {
#         text: "<p>La fermata \"Gare\" di Bitche è stata spostata davanti al ristorante della stazione per tutta la durata dei lavori. </p>"
#         language: "it"
#       }
#       translation {
#         text: "<p>De halte \"Gare\" in Bitche is voor de duur van de werken verplaatst vooraan de stationsrestauratie. </p>"
#         language: "nl"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::2954061528204511609:LOC"
#   alert {
#     active_period {
#       start: 1750849620
#       end: 1751925540
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876601F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876607F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876603F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876604F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86964F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86960F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876611F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86994F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86996F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86990F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86992F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86987F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86989F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86998F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86973F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86972F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86975F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86974F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86971F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86970F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86969F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN873994F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86966F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86967F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86984F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86983F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86985F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86981F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86977F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86979F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN86978F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876205F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877536F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877537F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876203F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876201F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877530F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877531F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876209F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876207F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876208F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877550F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877551F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876220F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877545F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876215F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877546F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876213F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877544F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877541F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876210F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877542F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876211F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876218F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876219F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877514F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877515F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877512F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877510F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877511F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877518F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877519F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877516F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877517F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877525F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877526F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877523F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877521F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877522F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877520F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877529F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877527F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877528F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877503F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877504F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877501F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877502F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877500F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877509F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877507F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877508F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877505F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877506F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877952F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876620F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877957F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876174F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876171F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876166F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876186F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876183F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876150F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876163F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876127F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876125F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876143F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876104F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876105F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876102F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876100F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876108F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876121F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876119F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN22441F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN22411F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876188F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459709R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459714R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459715R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459705R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459703R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459704R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876546F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876542F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877855F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877856F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877852F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877857F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877865F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876534F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876532F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877860F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876538F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79003R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79009R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79010R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79013R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79014R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79012R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79018R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79015R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79016R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457001R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457003R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457002R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457004R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79041R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79058R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79056R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79059R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN17311F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN17315F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN17313F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN17319F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79022R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN17317F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79028R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79029R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79026R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79031R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79032R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79030R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79033R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79034R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79039R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457090R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457091R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79093R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79097R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79096R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457081R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457080R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457083R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457082R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457085R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457084R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457087R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457086R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457089R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457088R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79061R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79066R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457070R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457072R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457071R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457074R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457073R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457076R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457075R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457078R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457077R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457079R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN79079R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457063R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457065R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457064R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457067R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457066R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457069R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457068R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN72004R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN72003R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN72002R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN72001R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457058R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457057R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457059R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459682R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459683R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459680R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459681R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459684R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN459685R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877701F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877706F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877703F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876425F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876423F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876424F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876421F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876422F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876420F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876429F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876427F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876428F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876432F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876433F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876430F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876431F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876403F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876404F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876402F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876400F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876409F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876407F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876408F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876405F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876406F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876414F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876412F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876413F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876410F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876411F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876419F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876416F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876417F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877712F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877713F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877716F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877714F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877715F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877723F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870600F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870603F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870602F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870601F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876369F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876366F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876364F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877682F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877683F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877680F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877681F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876350F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876348F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877679F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876349F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876346F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877677F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876347F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877678F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876344F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877675F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876345F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877676F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876342F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877673F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876343F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877674F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876362F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877691F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876360F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876361F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877690F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876359F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877688F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876357F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877689F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877686F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877687F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876356F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877684F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877685F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN23018F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN23016F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN23014F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN23012F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN23010F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878918F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878913F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876708F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876709F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876706F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876707F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876704F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876705F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876702F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876703F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876711F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876712F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876710F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876717F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876715F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876716F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876713F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876714F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877660F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877661F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878991F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877657F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878989F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877658F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877655F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877656F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878986F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877653F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877654F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878984F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877651F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878983F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876321F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877652F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877659F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877671F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876341F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877672F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877670F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876337F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877668F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877669F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876336F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877667F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877664F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876334F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877665F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877662F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877663F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876304F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876302F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876303F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878962F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876301F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878961F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876309F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878969F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876306F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876307F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878981F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877650F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876316F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877647F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876313F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876314F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876318F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878951F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878950F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878959F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN878957F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457231R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457221R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457220R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457223R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457222R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457225R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457224R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457227R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457226R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457229R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876252F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877584F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876253F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876250F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877582F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876251F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877580F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457210R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876245F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457212R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457211R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877575F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457214R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457213R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457216R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457218R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457217R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877594F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876263F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877595F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876261F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877593F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876262F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876260F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876258F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876259F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876256F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876257F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457201R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876254F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457200R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876255F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457203R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457202R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457205R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457204R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457207R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457206R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457209R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN457208R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876230F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877561F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877562F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877558F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876227F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877559F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876228F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876226F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877554F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876223F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877555F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877552F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876221F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877553F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876222F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876229F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876238F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876236F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876237F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876234F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877566F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877563F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876232F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN877564F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN876233F"
#       }
#     }
#     effect: UNKNOWN_EFFECT
#     header_text {
#       translation {
#         text: "Ankündigung eines Dienstwechsels"
#         language: "de"
#       }
#       translation {
#         text: "Annonce changement de service"
#         language: "fr"
#       }
#       translation {
#         text: "Anuncio de cambio de servicio"
#         language: "es"
#       }
#       translation {
#         text: "Service change announcement"
#         language: "en"
#       }
#       translation {
#         text: "Annuncio di cambio di servizio"
#         language: "it"
#       }
#       translation {
#         text: "Aankondiging van verandering van dienst"
#         language: "nl"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Ab Samstag, dem 5. Juli, ändern sich die Fahrpläne Ihres liO-Zuges.</p><p>Sie finden die Details der Fahrten über den neuen Service liO trafic, über den X-Feed @lio_train_sncf, SNCF Connect oder jede andere Mobilitätsanwendung.</p>"
#         language: "de"
#       }
#       translation {
#         text: "<p>A partir du samedi 5 juillet les horaires de vos Train liO évoluent.</p><p>Retrouvez le détail des circulations en vous connectant sur le nouveau service liO trafic, sur le fil X @lio_train_sncf, SNCF Connect ou toute autre application de mobilité.</p>"
#         language: "fr"
#       }
#       translation {
#         text: "<p>A partir del sábado 5 de julio, los horarios de El tren de liO cambiarán.</p><p>Puedes encontrar detalles de los servicios de tren conectándote al nuevo servicio de tráfico liO, al feed X @lio_train_sncf, a SNCF Connect o a cualquier otra aplicación de movilidad.</p>"
#         language: "es"
#       }
#       translation {
#         text: "<p>From Saturday July 5, the timetables of your Train liO are changing.</p><p>To find out more, log on to the new liO traffic service, the X feed @lio_train_sncf, SNCF Connect or any other mobility application.</p>"
#         language: "en"
#       }
#       translation {
#         text: "<p>Da sabato 5 luglio, gli orari di Il treno liO cambieranno.</p><p>Potete trovare i dettagli dei servizi ferroviari collegandovi al nuovo servizio di traffico liO, al feed X @lio_train_sncf, a SNCF Connect o a qualsiasi altra applicazione di mobilità.</p>"
#         language: "it"
#       }
#       translation {
#         text: "<p>Vanaf zaterdag 5 juli verandert de dienstregeling van je liO trein.</p><p>Je kunt de details van de treindiensten vinden door in te loggen op de nieuwe liO verkeersdienst, de X feed @lio_train_sncf, SNCF Connect of een andere mobiliteitstoepassing.</p>"
#         language: "nl"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::2053412200949249832:LOC"
#   alert {
#     active_period {
#       start: 1750850040
#       end: 1751925540
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870064F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870063F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870062F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN462169R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870061F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870068F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870067F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870066F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN462162R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870074F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870073F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870079F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN462154R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN462155R"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870060F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870053F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870052F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870051F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870050F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870057F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870056F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870055F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870054F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870059F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870058F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870024F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870021F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870027F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870033F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870002F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870001F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870000F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870006F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870005F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870004F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870003F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870009F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870008F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870007F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870013F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870012F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870011F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN870010F"
#       }
#     }
#     informed_entity {
#       trip {
# ...
#         text: "<p>Il macchinista deve effettuare un controllo tecnico sul treno prima che questo possa ripartire.</p>"
#         language: "it"
#       }
#       translation {
#         text: "<p>De machinist moet een technische controle op de trein uitvoeren voordat de trein weer kan vertrekken.</p>"
#         language: "nl"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::3967318002551581756:LOC"
#   alert {
#     active_period {
#       start: 1751449800
#       end: 1751481660
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN866828F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN866830F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "TER 866828, 866830 du 02/07/25   : arrêts supplémentaires"
#         language: "fr"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Le TER 866828, 866830 du 02/07/25 fera un arrêt supplémentaire dans les gares de : Cérons et Barsac.</p><p>Rendez-vous sur votre site TER Nouvelle-Aquitaine, sur SNCF Connect ou toute autre application de mobilité. </p>"
#         language: "fr"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::4970586447031657981:LOC"
#   alert {
#     active_period {
#       start: 1751449860
#       end: 1751525400
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN893904F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN893903F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "Die Wartungsarbeiten am Netzwerk wurden verspätet abgeschlossen."
#         language: "de"
#       }
#       translation {
#         text: "Les travaux de maintenance du réseau se sont terminés avec du retard."
#         language: "fr"
#       }
#       translation {
#         text: "Los trabajos de mantenimiento de la red finalizaron con retraso."
#         language: "es"
#       }
#       translation {
#         text: "Network maintenance work was completed late."
#         language: "en"
#       }
#       translation {
#         text: "I lavori di manutenzione della rete sono stati completati in ritardo."
#         language: "it"
#       }
#       translation {
#         text: "De netwerkonderhoudswerkzaamheden zijn te laat afgerond."
#         language: "nl"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Die Wartungsarbeiten am Netzwerk wurden verspätet abgeschlossen.</p>"
#         language: "de"
#       }
#       translation {
#         text: "<p>Les travaux de maintenance du réseau se sont terminés avec du retard.</p>"
#         language: "fr"
#       }
#       translation {
#         text: "<p>Los trabajos de mantenimiento de la red finalizaron con retraso.</p>"
#         language: "es"
#       }
#       translation {
#         text: "<p>Network maintenance work was completed late.</p>"
#         language: "en"
#       }
#       translation {
#         text: "<p>I lavori di manutenzione della rete sono stati completati in ritardo.</p>"
#         language: "it"
#       }
#       translation {
#         text: "<p>De netwerkonderhoudswerkzaamheden zijn te laat afgerond.</p>"
#         language: "nl"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::5017831182768037815:LOC"
#   alert {
#     active_period {
#       start: 1751449860
#       end: 1751453460
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN2864F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "Votre train est retardé."
#         language: "fr"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p></p><p>Cause : retard de votre rame lors de son précédent trajet à LUXEMBOURG </p>"
#         language: "fr"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::2409590719737243238:LOC"
#   alert {
#     active_period {
#       start: 1751449920
#       end: 1751465100
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN9862F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN5062F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "Der Verkehr verlangsamt sich ."
#         language: "de"
#       }
#       translation {
#         text: "Le trafic est ralenti."
#         language: "fr"
#       }
#       translation {
#         text: "El tráfico se está ralentizando ."
#         language: "es"
#       }
#       translation {
#         text: "Traffic is slowing down ."
#         language: "en"
#       }
#       translation {
#         text: "Il traffico sta rallentando ."
#         language: "it"
#       }
#       translation {
#         text: "Het verkeer neemt af ."
#         language: "nl"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Unsere Teams reagieren derzeit. </p><p></p><p> Ursache: Störung eines anderen Zuges auf der Strecke, die den Betrieb Ihres Zuges in VALENCE TGV RHÔNE-ALPES SUD beeinträchtigt.</p>"
#         language: "de"
#       }
#       translation {
#         text: "<p>Nos équipes sont en cours d\'intervention.</p><p></p><p>Cause : panne d\'un autre train sur la ligne affectant la circulation de votre train à VALENCE TGV RHÔNE-ALPES SUD.</p>"
#         language: "fr"
#       }
#       translation {
#         text: "<p>Nuestros equipos están respondiendo actualmente. </p><p></p><p> Causa: avería de otro tren en la línea que afecta a la circulación de su tren en VALENCE TGV RHÔNE-ALPES SUD .</p>"
#         language: "es"
#       }
#       translation {
#         text: "<p>Our teams are currently responding. </p><p></p><p> Cause: breakdown of another train on the line affecting the running of your train at VALENCE TGV RHÔNE-ALPES SUD .</p>"
#         language: "en"
#       }
#       translation {
#         text: "<p>I nostri team stanno rispondendo in questo momento. </p><p></p><p> Causa: guasto di un altro treno sulla linea che influisce sulla circolazione del vostro treno a VALENCE TGV RHÔNE-ALPES SUD .</p>"
#         language: "it"
#       }
#       translation {
#         text: "<p>Onze teams zijn momenteel bezig met reageren. </p><p></p><p> Oorzaak: een storing van een andere trein op het traject die gevolgen heeft voor de rit van uw trein op het traject VALENCE TGV RHÔNE-ALPES SUD .</p>"
#         language: "nl"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::1031679806462147460:LOC"
#   alert {
#     active_period {
#       start: 1751449980
#       end: 1751453580
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN7671F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "Votre train est retardé."
#         language: "fr"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p></p><p>Cause : ralentissement d\'un train circulant devant le vôtre entre BORDEAUX  et AGEN .</p>"
#         language: "fr"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::9021332352086297635:LOC"
#   alert {
#     active_period {
#       start: 1751449980
#       end: 1751457720
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN835020F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "Der Zug wurde aufgrund einer Verspätung bei einer vorherigen Fahrt verspätet bereitgestellt."
#         language: "de"
#       }
#       translation {
#         text: "Le train a été mis à disposition tardivement à la suite du retard sur un trajet précédent."
#         language: "fr"
#       }
#       translation {
#         text: "El tren estuvo disponible con retraso debido a una demora en un viaje anterior."
#         language: "es"
#       }
#       translation {
#         text: "The train was made available late following a delay on a previous journey."
#         language: "en"
#       }
#       translation {
#         text: "Il treno è stato reso disponibile in ritardo a causa di un ritardo in un viaggio precedente."
#         language: "it"
#       }
#       translation {
#         text: "De trein werd pas laat beschikbaar gesteld vanwege een vertraging op een eerdere reis."
#         language: "nl"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Der Zug wurde aufgrund einer Verspätung bei einer vorherigen Fahrt verspätet bereitgestellt.</p>"
#         language: "de"
#       }
#       translation {
#         text: "<p>Le train a été mis à disposition tardivement à la suite du retard sur un trajet précédent.</p>"
#         language: "fr"
#       }
#       translation {
#         text: "<p>El tren estuvo disponible con retraso debido a una demora en un viaje anterior.</p>"
#         language: "es"
#       }
#       translation {
#         text: "<p>The train was made available late following a delay on a previous journey.</p>"
#         language: "en"
#       }
#       translation {
#         text: "<p>Il treno è stato reso disponibile in ritardo a causa di un ritardo in un viaggio precedente.</p>"
#         language: "it"
#       }
#       translation {
#         text: "<p>De trein werd pas laat beschikbaar gesteld vanwege een vertraging op een eerdere reis.</p>"
#         language: "nl"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::467893249812539289:LOC"
#   alert {
#     active_period {
#       start: 1751450040
#       end: 1751484660
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN866733F"
#       }
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN866735F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "TER 866733, 866735 du 02/07/25   : arrêts supplémentaires"
#         language: "fr"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Le TER 866733, 866735 du 02/07/25 fera un arrêt supplémentaire dans les gares de : Barsac.</p><p>Rendez-vous sur votre site TER Nouvelle-Aquitaine, sur SNCF Connect ou toute autre application de mobilité. </p>"
#         language: "fr"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::6949097147200540619:LOC"
#   alert {
#     active_period {
#       start: 1751450100
#       end: 1751455260
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN858350F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "858350 supprimé"
#         language: "fr"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Accident de personne. 858350 Nantes 12h05 Rennes 13h21 est supprimé. Empruntez 857712 Nantes 12h04 Rennes 14h21. Vérifiez vos horaires sur le <span style=\"color:#333333\">site </span><span style=\"color:#333333\"><a href=\"https://www.ter.sncf.com/pays-de-la-loire\">TER Pays de La Loire</a>, <a href=\"https://www.sncf-connect.com/\">SNCF Connect</a> ou vos applications de mobilité.</span></p>"
#         language: "fr"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::1092066663673654880:LOC"
#   alert {
#     active_period {
#       start: 1751450160
#       end: 1751454000
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN9203F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "Der Verkehr verlangsamt sich ."
#         language: "de"
#       }
#       translation {
#         text: "Le trafic est ralenti."
#         language: "fr"
#       }
#       translation {
#         text: "El tráfico se está ralentizando ."
#         language: "es"
#       }
#       translation {
#         text: "Traffic is slowing down ."
#         language: "en"
#       }
#       translation {
#         text: "Il traffico sta rallentando ."
#         language: "it"
#       }
#       translation {
#         text: "Het verkeer neemt af ."
#         language: "nl"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Unsere Teams sind im Einsatz.</p><p></p><p>Ursache: Störung an einem anderen Zug auf der Linie, die den Verkehr Ihres Zuges zwischen BELFORT  - MONTBÉLIARD TGV und MULHOUSE beeinträchtigt . </p>"
#         language: "de"
#       }
#       translation {
#         text: "<p>Nos équipes sont en cours d\'intervention.</p><p></p><p>Cause : panne d\'un autre train sur la ligne affectant la circulation de votre train entre  BELFORT - MONTBÉLIARD TGV et  MULHOUSE.</p>"
#         language: "fr"
#       }
#       translation {
#         text: "<p>Nuestros equipos están interviniendo.</p><p></p><p>Causa: Avería de otro tren en la línea que afecta a su tren entre  Belfort - Montbéliard TGV y  Mulhouse.</p>"
#         language: "es"
#       }
#       translation {
#         text: "<p>Our teams are in the process of intervening.</p><p></p><p>Cause : Breakdown of another train on the Line affecting your Train between BELFORT  - MONTBÉLIARD TGV and MULHOUSE. </p>"
#         language: "en"
#       }
#       translation {
#         text: "<p>Le nostre squadre stanno intervenendo.</p><p></p><p>Causa: guasto di un altro treno sulla Linea che interessa il vostro treno tra  Belfort - Montbéliard TGV e  Mulhouse.</p>"
#         language: "it"
#       }
#       translation {
#         text: "<p>Onze teams zijn aan het werk.</p><p></p><p>Oorzaak: Uitval van een andere trein op de spoorlijn tussen  Belfort - Montbéliard TGV en  Mulhouse.</p>"
#         language: "nl"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::3746462682852988183:LOC"
#   alert {
#     active_period {
#       start: 1751450160
#       end: 1751459400
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN7851F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "Der Verkehr verlangsamt sich ."
#         language: "de"
#       }
#       translation {
#         text: "Le trafic est ralenti."
#         language: "fr"
#       }
#       translation {
#         text: "El tráfico se está ralentizando ."
#         language: "es"
#       }
#       translation {
#         text: "Traffic is slowing down ."
#         language: "en"
#       }
#       translation {
#         text: "Il traffico sta rallentando ."
#         language: "it"
#       }
#       translation {
#         text: "Het verkeer neemt af ."
#         language: "nl"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p>Unsere Teams reagieren derzeit. </p><p></p><p> Ursache: Störung eines anderen Zuges auf der Strecke, die den Betrieb Ihres Zuges bei VALENCE TGV beeinträchtigt.</p>"
#         language: "de"
#       }
#       translation {
#         text: "<p>Nos équipes sont en cours d\'intervention.</p><p></p><p>Cause : panne d\'un autre train sur la ligne affectant la circulation de votre train à VALENCE TGV.</p>"
#         language: "fr"
#       }
#       translation {
#         text: "<p>Nuestros equipos están respondiendo actualmente. </p><p></p><p> Causa: avería de otro tren en la línea que afecta a la circulación de su tren en VALENCE TGV .</p>"
#         language: "es"
#       }
#       translation {
#         text: "<p>Our teams are currently responding. </p><p></p><p> Cause: breakdown of another train on the line affecting the running of your train at VALENCE TGV .</p>"
#         language: "en"
#       }
#       translation {
#         text: "<p>I nostri team stanno rispondendo in questo momento. </p><p></p><p> Causa: guasto di un altro treno sulla linea che influisce sulla circolazione del vostro treno a VALENCE TGV .</p>"
#         language: "it"
#       }
#       translation {
#         text: "<p>Onze teams zijn momenteel bezig met reageren. </p><p></p><p> Oorzaak: een storing van een andere trein op het spoor die gevolgen heeft voor de rit van uw trein op VALENCE TGV .</p>"
#         language: "nl"
#       }
#     }
#     severity_level: INFO
#   }
# }
# entity {
#   id: "QOM:Broadcast::7266300636552330657:LOC"
#   alert {
#     active_period {
#       start: 1751450160
#       end: 1751453760
#     }
#     informed_entity {
#       trip {
#         trip_id: "OCESN2406F"
#       }
#     }
#     cause: OTHER_CAUSE
#     header_text {
#       translation {
#         text: "Votre train est retardé."
#         language: "fr"
#       }
#     }
#     description_text {
#       translation {
#         text: "<p></p><p>Cause : retard de votre rame lors de son précédent trajet à STRASBOURG </p>"
#         language: "fr"
#       }
#     }
#     severity_level: INFO
#   }
# }

# %%
all_data = []
all_ids = []
if feed:
    for entity in feed.entity:
        entity_data = {}
        entity_data['id'] = entity.id
        all_ids.append(entity.id)
        entity_data['alert'] = entity.alert
        all_data.append(entity_data)

# %%
all_data[0]

# %% [markdown]
# ### GTFS

# %%
import os
import zipfile

# %%
GTFS_URL = 'https://eu.ftp.opendatasoft.com/sncf/plandata/export_gtfs_voyages.zip'

# %%
def download_gtfs_data(url: str):
    """
    Fetch GTFS files from source
    """
    try:
        r = requests.get(url)
        r.raise_for_status()
        return r.content
    except Exception as e:
        raise e

# %%
def extract_data_from_zip(data: bytes):
    if not os.path.exists('tmp_gtfs'):
        os.makedirs('tmp_gtfs')
    with open('tmp_gtfs/raw_gtfs.zip', 'wb') as f:
        f.write(data)
    with zipfile.ZipFile('tmp_gtfs/raw_gtfs.zip', 'r') as zip_ref:
        zip_ref.extractall('tmp_gtfs')
    os.remove('tmp_gtfs/raw_gtfs.zip')
    return

# %%
def remove_tmp_files():
    for file in os.listdir('tmp_gtfs'):
        os.remove(os.path.join('tmp_gtfs', file))
    os.rmdir('tmp_gtfs')
    return

# %%
data = download_gtfs_data(GTFS_URL)
extract_data_from_zip(data)
# Insérer dans BDD ici
remove_tmp_files()
